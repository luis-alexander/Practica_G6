# %% [markdown]
# ### Dominio de negocio
#
# El dominio de negocio seleccionado es el área de ventas. Con las fuentes de datos proporcionadas se desarrollaron las etapas de extracción, transformación y carga (ETL), permitiendo disponer de información organizada y lista para su análisis.
#
# Link de fuentes: https://www.kaggle.com/datasets/thedevastator/unlock-profits-with-e-commerce-sales-data
#
# - Extracción (Extract): se obtuvieron los datos desde archivos estructurados en formato CSV y otras fuentes relacionadas con las ventas.
# - Transformación (Transform): se realizaron tareas de limpieza, validación, eliminación de registros inconsistentes, integración de datos y normalización de atributos como categorías, tallas y colores, con el objetivo de garantizar la calidad y consistencia de la información.
# - Carga (Load): finalmente, los datos transformados fueron almacenados en una base de datos PostgreSQL para facilitar su consulta y posterior análisis mediante herramientas de inteligencia de negocios.

# %% [markdown]
# # DataFrame desde PostgreSQL
# En esta sección se crea el DataFrame principal a partir de la tabla almacenada en PostgreSQL y se realiza una exploración inicial de los datos.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# %% [markdown]
# ## Carga de variables de entorno
#
# Se cargan las credenciales de conexión almacenadas en el archivo ".env`" para evitar escribir directamente datos sensibles en el notebook.

# %%
load_dotenv()
DB_USER = os.getenv("POSTGRES_USER")
DB_PASSWORD = os.getenv("POSTGRES_PASSWORD")
DB_NAME = os.getenv("POSTGRES_DB")
DB_PORT = os.getenv("POSTGRES_PORT")
DB_HOST = "127.0.0.1"

# %% [markdown]
# ## Creación del motor de conexión
#
# Se construye el engine de SQLAlchemy para establecer la conexión con PostgreSQL.

# %%
engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# %% [markdown]
# ## Validación de la conexión
#
# Se ejecuta una consulta simple para comprobar que la conexión a la base de datos funciona correctamente.

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT 1"))
    print("Conexión exitosa:", result.scalar())
# Out:
# Conexión exitosa: 1

# %% [markdown]
# ## Carga de la tabla como DataFrame
#
# Se consulta la tabla `sale_report` del esquema `public` y se almacena el resultado en un DataFrame para su posterior análisis.

# %%
df_bd = pd.read_sql("SELECT * FROM public.sale_report", engine)

# %% [markdown]
# ## Primeras 5 filas del DataFrame
# Se visualizan las primeras cinco filas del DataFrame para conocer la estructura inicial de la información.

# %%
df_bd.head()
# Out:
#    index       SKU Code Design No.  stock       category size color
# 0      0    AN201-RED-L      AN201    5.0  AN : LEGGINGS    L   Red
# 1      1    AN201-RED-M      AN201    5.0  AN : LEGGINGS    M   Red
# 2      2    AN201-RED-S      AN201    3.0  AN : LEGGINGS    S   Red
# 3      3   AN201-RED-XL      AN201    6.0  AN : LEGGINGS   XL   Red
# 4      4  AN201-RED-XXL      AN201    3.0  AN : LEGGINGS  XXL   Red

# %% [markdown]
# ## Columnas con valores nulos
# Se identifican las columnas que presentan al menos un valor nulo

# %%
columnas_con_nulos = df_bd.columns[df_bd.isnull().any()]
print("Columnas con valores nulos:")
print(columnas_con_nulos.tolist())
# Out:
# Columnas con valores nulos:
# ['SKU Code', 'Design No.', 'stock', 'category', 'size', 'color']

# %% [markdown]
# ## Conteo de valores faltantes por columna
# Se cuantifica cuántos valores faltan en cada columna del DataFrame.

# %%
faltantes_por_columna = df_bd.isnull().sum()
print("Valores faltantes por columna:")
print(faltantes_por_columna)
# Out:
# Valores faltantes por columna:
# index          0
# SKU Code      83
# Design No.    36
# stock         36
# category      45
# size          36
# color         45
# dtype: int64

# %% [markdown]
# ## Tipos de datos y selección de variables numéricas
# Se identifican las columnas numéricas disponibles para calcular estadísticas descriptivas.

# %%
print(df_bd.dtypes)
print(df_bd.columns.tolist())
# Out:
# index           int64
# SKU Code          str
# Design No.        str
# stock         float64
# category          str
# size              str
# color             str
# dtype: object
# ['index', 'SKU Code', 'Design No.', 'stock', 'category', 'size', 'color']

# %% [markdown]
# ## Estadísticas de la variable numérica seleccionada
# Se calcula el promedio, el valor máximo y el valor mínimo de la variable `stock`.

# %%
df_bd["stock"].agg(["mean", "max", "min"])
# Out:
# mean      26.246454
# max     1234.000000
# min        0.000000
# Name: stock, dtype: float64

# %% [markdown]
# ## Máximo y mínimo agrupado
# Se calcula el valor máximo y mínimo de la variable `stock` agrupando

# %%
df_bd.groupby("category")["stock"].agg(["max", "min"])
# Out:
#                          max   min
# category
# AN : LEGGINGS           23.0   0.0
# BLOUSE                 628.0   0.0
# BOTTOM                   4.0   0.0
# CARDIGAN                11.0   0.0
# CROP TOP                45.0   2.0
# CROP TOP WITH PLAZZO   232.0  11.0
# DRESS                  441.0   0.0
# JUMPSUIT                11.0   2.0
# KURTA                 1234.0   0.0
# KURTA SET              880.0   0.0
# KURTI                   72.0  30.0
# LEHENGA CHOLI           72.0   0.0
# NIGHT WEAR              72.0   1.0
# PALAZZO                 55.0   1.0
# PANT                   398.0   0.0
# SAREE                   93.0   0.0
# SET                    310.0   0.0
# SHARARA                 42.0  17.0
# SKIRT                   38.0  29.0
# TOP                    315.0   0.0
# TUNIC                  157.0   0.0

# %% [markdown]
# ### Aplicación Profesional de la Práctica

# %% [markdown]
# ## SANTIAGO BRAVO
#
# El área profesional en la que me desempeño está relacionada con las telecomunicaciones,
# las redes de datos y la operación de servicios ISP. En este entorno se gestionan grandes
# volúmenes de información técnica y operativa que resultan fundamentales para garantizar la
# disponibilidad, el rendimiento y la calidad del servicio ofrecido a los usuarios. Entre los datos
# más relevantes se encuentran los registros de tráfico de red, consumo de ancho de banda,
# eventos de dispositivos, alarmas de caídas, tickets de soporte, inventario de equipos, estadísticas
# de enlace, tiempos de respuesta y reportes de incidencias. Todos estos datos se generan de
# manera continua y provienen de múltiples fuentes, por lo que su integración y análisis son clave
# para una gestión eficiente.
# En este contexto, PostgreSQL podría utilizarse como repositorio central para almacenar
# información estructurada proveniente de distintas fuentes, como archivos CSV, registros
# exportados desde herramientas de monitoreo o reportes generados por plataformas de red.
# Docker permitiría desplegar de forma rápida y ordenada el entorno de base de datos, asegurando
# portabilidad, facilidad de configuración y replicabilidad del proyecto en diferentes equipos de
# trabajo. Por su parte, Python facilitaría el desarrollo del proceso ETL, permitiendo extraer datos
# desde archivos o sistemas, transformarlos para limpiarlos, normalizarlos y estructurarlos, y
# finalmente cargarlos en la base de datos para su posterior análisis. Esta integración tecnológica
# permitiría automatizar tareas que normalmente se realizan de forma manual y reducir errores
# en el manejo de la información.
# La implementación de un proceso ETL en una organización del sector de
# telecomunicaciones aportaría beneficios importantes. En primer lugar, permitiría consolidar
# datos dispersos en una sola fuente confiable, facilitando la consulta y comparación de
# información histórica y actual. En segundo lugar, mejoraría la velocidad de análisis para
# detectar patrones de fallas, saturación de enlaces o comportamientos anómalos en la red.
# También ayudaría a optimizar la toma de decisiones técnicas y operativas, ya que los
# responsables podrían trabajar con datos más limpios, organizados y accesibles. Finalmente,
# contribuiría a generar reportes más claros y útiles para la supervisión de indicadores de
# desempeño y calidad del servicio.
# A partir de la información obtenida mediante este tipo de análisis, sería posible resolver
# problemas como la identificación de nodos con alta congestión, la detección de horarios de
# mayor demanda, la priorización de mantenimientos preventivos, la mejora en la atención de
# incidentes y la planificación de ampliaciones de capacidad. En conclusión, considero que los
# conocimientos adquiridos en esta práctica tienen una aplicación directa en el ámbito de
# telecomunicaciones y redes, ya que permiten transformar datos operativos en información útil
# para mejorar la eficiencia, la continuidad del servicio y la toma de decisiones dentro de una
# organización.

# %% [markdown]
# ## YHORDAN GUERRON
#
# Actualmente me desempeño en el área comercial y de negociación de mercadería importada,
# aunque mi formación académica está orientada a la ingeniería en ciberseguridad. Considero que
# los conocimientos adquiridos en esta práctica son de gran utilidad tanto para mi trabajo actual
# como para mi desarrollo profesional futuro, ya que las organizaciones dependen cada vez más
# de la gestión y análisis de datos para la toma de decisiones.
# En el entorno comercial se generan diversos tipos de datos, como registros de ventas,
# inventarios, información de proveedores, órdenes de compra, precios, promociones y
# comportamiento de los clientes. Por otro lado, en el ámbito de la ciberseguridad también se
# manejan datos relacionados con eventos de red, registros de acceso, alertas de seguridad y
# monitoreo de sistemas. Todos estos datos pueden convertirse en información valiosa cuando
# son almacenados y analizados adecuadamente.
# Las herramientas utilizadas en esta práctica permiten gestionar eficientemente dichos datos.
# PostgreSQL puede emplearse para almacenar información de manera estructurada y segura,
# facilitando las consultas y el acceso a grandes volúmenes de datos. Docker permite desplegar
# aplicaciones y bases de datos en entornos aislados y fáciles de administrar, reduciendo
# problemas de compatibilidad entre sistemas. Por su parte, Python ofrece una amplia variedad
# de librerías para la manipulación, limpieza y análisis de datos, permitiendo automatizar
# procesos y generar reportes de manera eficiente.
# La implementación de un proceso ETL (Extracción, Transformación y Carga) aportaría
# importantes beneficios a cualquier organización. Este proceso permite integrar información
# proveniente de múltiples fuentes, depurar datos inconsistentes y consolidarlos en una única base
# de datos para su posterior análisis. Esto mejora la calidad de la información, reduce errores
# manuales y optimiza el tiempo requerido para obtener resultados.
# Tomando en cuenta lo antes mencionado, el análisis de los datos obtenidos puede apoyar la
# toma de decisiones estratégicas. En el área comercial permitiría identificar productos con mayor
# demanda, optimizar inventarios y evaluar el desempeño de las ventas. En el ámbito de la
# ciberseguridad facilitaría la detección de comportamientos anómalos, la identificación de
# vulnerabilidades y la respuesta temprana ante posibles incidentes. Por estas razones, considero
# que los conocimientos desarrollados en esta práctica representan una base importante para
# mejorar la gestión de la información y fortalecer los procesos de cualquier organización.

# %% [markdown]
# ## ALEXANDER SOTO
#
# Actualmente me desempeño como Analista de Seguridad (SOC), enfocado en el monitoreo
# y análisis de eventos de ciberseguridad, así como en la identificación y gestión de incidentes
# que puedan afectar la disponibilidad, integridad y confidencialidad de la información, creo que
# los conocimientos adquiridos en esta práctica tienen una aplicación directa en mi entorno
# laboral, ya que las operaciones de ciberseguridad generan grandes volúmenes de información
# que requieren ser almacenados, procesados y analizados de manera eficiente para apoyar la
# toma de decisiones.
# En el entorno de un Centro de Operaciones de Seguridad se generan y gestionan diversos
# tipos de datos, entre los que se encuentran registros de eventos provenientes de firewalls,
# sistemas de detección y prevención de intrusiones, plataformas SIEM, autenticaciones de
# usuarios, eventos de sistemas operativos, alertas de antivirus, conexiones de red y registros de
# aplicaciones, toda esta información constituye una fuente valiosa para identificar
# comportamientos anómalos, detectar amenazas y realizar investigaciones de seguridad.
# Las tecnologías utilizadas en esta práctica permiten administrar y aprovechar estos datos de
# manera eficiente, PostgreSQL puede emplearse para almacenar información estructurada
# relacionada con eventos de seguridad, incidentes y métricas operativas. Docker facilita el
# despliegue de entornos aislados y portables, permitiendo implementar soluciones de análisis y
# procesamiento sin afectar otros servicios. Por su parte, Python proporciona una amplia variedad
# de librerías para automatizar tareas, transformar datos, generar reportes y realizar análisis que
# contribuyan a mejorar la visibilidad y capacidad de respuesta ante incidentes.
# La implementación de procesos ETL permitiría integrar información proveniente de
# diferentes herramientas de seguridad, consolidando los datos en una única fuente confiable.
# Esto contribuiría a mejorar la calidad de la información, reducir actividades manuales,
# optimizar tiempos de análisis y facilitar la generación de reportes y métricas para la gestión de
# la seguridad.
# Para concluir se afirma que el análisis de la información obtenida permitiría identificar
# patrones de comportamiento sospechoso, detectar tendencias de ataques, evaluar el desempeño
# de los controles de seguridad y priorizar incidentes de acuerdo con su impacto, asimismo,
# facilitaría la toma de decisiones orientadas a fortalecer la postura de seguridad de la
# organización, mejorar los tiempos de respuesta y optimizar los procesos de monitoreo y gestión
# de eventos dentro del Centro de Operaciones de Seguridad.
